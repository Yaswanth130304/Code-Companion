# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY="AIzaSyDy0mlAfaGhfoLCwp0o10SvjD7ZF7_L61U"

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 for m in genai.list_models():
#       2   if 'generateContent' in m.supported_generation_methods:
#       3     print(m.name)
#
# File ~\anaconda3\Lib\site-packages\google\generativeai\models.py:206, in list_models(page_size, client, request_options)
#     204 for model in client.list_models(page_size=page_size, **request_options):
#     205     model = type(model).to_dict(model)
# --> 206     yield model_types.Model(**model)
#
# TypeError: Model.__init__() got an unexpected keyword argument 'max_temperature'

# %%
model = genai.GenerativeModel('gemini-1.5-pro')

# %%
# %%time
response = model.generate_content("Question: A gene is represented as a string of length $n$ (where $n$ is divisible by $4$), composed of the letters $\\mbox{A}$, $\\mbox{C}$, $\\textbf{T}$, and $\\mbox{G}$.\nIt is considered to be steady if each of the four letters occurs exactly $\\frac{n}{4}$ times.  For example, $\\textbf{GACT}$ and $\\textbf{AAGTGCCT}$ are both steady genes.\n\nBear Limak is a famous biotechnology scientist who specializes in modifying bear DNA to make it steady.  Right now, he is examining a gene represented as a string $\\textit{gene}$.  It is not necessarily steady.  Fortunately, Limak can choose one (maybe empty) substring of $\\textit{gene}$ and replace it with any string of the same length.\n\nModifying a large substring of bear genes can be dangerous.\nGiven a string $\\textit{gene}$, can you help Limak find the length of the smallest possible substring that he can replace to make $\\textit{gene}$ a steady gene?\n\nNote: A substring of a string $\\boldsymbol{\\mathrm{~S~}}$ is a subsequence made up of zero or more contiguous characters of $\\boldsymbol{\\mathrm{~S~}}$.\n\nAs an example, consider $\\textit{gene}=\\textit{ACTGAAAG}$.  The substring $\\boldsymbol{AA}$ just before or after $\\mbox{G}$ can be replaced with $\\textit{CT}$ or $\\boldsymbol{TC}$.  One selection would create $\\textbf{ACTGACTG}$.\n\nFunction Description\n\nComplete the $\\textit{steadyGene}$ function in the editor below.  It should return an integer that represents the length of the smallest substring to replace.  \n\nsteadyGene has the following parameter:  \n\ngene: a string\n\nInput Format\n\nThe first line contains an interger $n$ divisible by $4$, that denotes the length of a string $\\textit{gene}$. \n\nThe second line contains a string $\\textit{gene}$ of length $n$.\n\nConstraints\n\n$4\\leq n\\leq500000$  \n$n$ is divisible by $4$  \n$gene[i]\\in[CGAT]$  \n\nSubtask  \n\n$4\\leq n\\leq2000$ in tests worth $30\\%$ points.\n\nOutput Format\n\nPrint the length of the minimum length substring that can be replaced to make $\\textit{gene}$ stable.\n\nSample Input\n8  \nGAAATAAA\n\nSample Output\n5\n\nExplanation\n\nOne optimal solution is to replace $\\textbf{AAATA}$ with $\\textbf{TTCCG}$ resulting in $\\textbf{GTTCCGAA}$. \n\nThe replaced substring has length $5$.. Difficulty: MEDIUM. Skills: []. Expected Time Complexity: None. Expected Auxiliary Space: None. convert the prompt to a better prompt for training my student llm  and also make it understand the test case and also prompt must not be too long and also and include extra information  if needed and also don't forget do not use emoji and also ask the model to generate the code.")
# Out:
# CPU times: total: 0 ns
# Wall time: 20.6 s

# %%
print(response.text)
# Out:
# ```python
# def steadyGene(gene):
#     """
#     Finds the length of the smallest substring that can be replaced to make a gene steady.
#
#     A gene is a string composed of 'A', 'C', 'G', and 'T'. It is considered steady
#     if each of the four letters occurs exactly n/4 times, where n is the length of the gene.
#
#     Args:
#         gene: The gene string.
#
#     Returns:
#         The length of the smallest substring to replace.
#     """
#
# ```
# Let's break down how to solve this problem and then you can implement the `steadyGene` function in Python.
#
# **Understanding the Problem**
#
# The problem focuses on finding the smallest substring within `gene` that needs replacement to make the entire gene "steady." A steady gene has an equal count of 'A', 'C', 'G', and 'T' nucleotides.
#
# **Solution Approach**
#
# 1. **Character Counts:** Calculate the frequency of each nucleotide ('A', 'C', 'G', 'T') in the input `gene`.
#
# ...

# %%
import json

# Specify the path to your JSON file
file_path = 'output.json'

# Initialize a list to store all the outputs
demo_1 = []

# Read JSON file
with open(file_path, 'r') as file:
    json_data = json.load(file)

    # Iterate over each JSON object in json_data
    for item in json_data:
        # Extract the 'output' field from each JSON object
        instruct_prompt = item['instruction']
        # Append the output code to the list
        demo_1.append(instruct_prompt)

# %%
print(demo_1[100])
# Out:
# Question: Ujan has been lazy lately, but now has decided to bring his yard to good shape. First, he decided to paint the path from his house to the gate.
#
# The path consists of $n$ consecutive tiles, numbered from $1$ to $n$. Ujan will paint each tile in some color. He will consider the path aesthetic if for any two different tiles with numbers $i$ and $j$, such that $|j - i|$ is a divisor of $n$ greater than $1$, they have the same color. Formally, the colors of two tiles with numbers $i$ and $j$ should be the same if $|i-j| > 1$ and $n \bmod |i-j| = 0$ (where $x \bmod y$ is the remainder when dividing $x$ by $y$).
#
# Ujan wants to brighten up space. What is the maximum number of different colors that Ujan can use, so that the path is aesthetic?
#
#
# -----Input-----
#
# The first line of input contains a single integer $n$ ($1 \leq n \leq 10^{12}$), the length of the path.
#
#
# -----Output-----
#
# ...

# %%
import json

# Specify the path to your JSON file
file_path = 'prompt_data/third_dataset.json'

# Initialize a list to store all the outputs
demo_2 = []

# Read JSON file
with open(file_path, 'r') as file:
    json_data = json.load(file)

    # Iterate over each JSON object in json_data
    for item in json_data:
        # Extract the 'output' field from each JSON object
        instruct_prompt = item['instruction']
        # Append the output code to the list
        demo_2.append(instruct_prompt)

# %%
print(demo_2[100])
# Out:
# Ujan wants to paint a path with 'n' tiles using the maximum number of colors possible. However, there's a rule: if the difference between the tile numbers 'i' and 'j' divides 'n' perfectly (excluding the case when |i-j|=1), then tiles 'i' and 'j' must have the same color.
#
# Your task is to write a Python program that takes an integer 'n' (representing the number of tiles) as input and outputs the maximum number of different colors Ujan can use while still following the rule.
#
# **Example:**
#
# 1. **Input:** n = 4
#    **Output:** 2
#    **Explanation:** Tiles 1 & 3 should have the same color, and tiles 2 & 4 should have the same color.
#
# 2. **Input:** n = 5
#    **Output:** 5
#    **Explanation:** All five tiles can be painted different colors as no difference between tile numbers (except 1) divides 5 perfectly.

# %%
len(all_instruct_prompt)
# Out:
# 19493

# %%
prompt_string =  "convert the prompt to a better prompt for training my student llm  and also make it understand the test case and also prompt must not be too long and also and include extra information  if needed and also don't forget do not use emoji and also ask the model to generate the code in python and also do not include the starter code."

# %%
response = model.generate_content(all_instruct_prompt[1200]+" "+ prompt_string)

# %%
print(response.text)
# Out:
# ##  Help Ivan Find Robot Bugs!
#
# Ivan's robot moves on a grid, following commands 'U' (up), 'D' (down), 'L' (left), and 'R' (right). Ivan gave the robot a sequence of commands, and surprisingly, it ended back at the starting point (0,0). However, Ivan suspects the robot might be ignoring some commands!
#
# Your task is to help Ivan determine the **maximum** number of commands the robot could have correctly followed while still ending up back at the starting position.
#
# **Input:**
# - The first line contains the number of commands (n).
# - The second line contains the command sequence as a string.
#
# **Output:**
# - Print a single integer representing the maximum number of commands the robot could have performed correctly.
#
# **Example:**
# Let's analyze the test case:
#
# Input:
# ```
# 6
# LLRRRR
# ```
#
# Output:
# ```
# 4
# ```
#
# Explanation:
# ...

# %%
all_instruct = []

# %%
len(all_instruct)
# Out:
# 0

# %%
len(all_instruct_prompt)
# Out:
# 19493

# %%
count = 0

# %%
for i in range(5693, 9748):
    try:
        response = model.generate_content(all_instruct_prompt[i] + " " + prompt_string)

        if response.text is None or response.text.strip() == "":
            # Handle the case where response text is None or empty
            all_instruct.append(all_instruct_prompt[i])
            print(f"Response for input {i} is None or empty, appended question string.")
        else:
            # Add valid response text to the list
            all_instruct.append(response.text)

    except Exception as e:
        # Handle any exceptions that occur
        all_instruct.append(all_instruct_prompt[i])
        count=count+1
        print(count)
        print(f"Exception occurred for input {i}: {str(e)}, appended empty string.")
        print(len(all_instruct))
# Out:
# 1
# Exception occurred for input 6061: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. Please check the `candidate.safety_ratings` to determine if the response was blocked., appended empty string.
# 369
# 2
# Exception occurred for input 6537: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. Please check the `candidate.safety_ratings` to determine if the response was blocked., appended empty string.
# 845
# 3
# Exception occurred for input 7051: Invalid operation: The `response.text` quick accessor requires the response to contain a valid `Part`, but none were returned. Please check the `candidate.safety_ratings` to determine if the response was blocked., appended empty string.
# 1359
# 4
# ...

# %%
len(all_instruct)
# Out:
# 4055

# %%
import json
file_path = 'prompt_data/part_one_4.json'

# Serialize Python list to JSON string
json_data = json.dumps(all_instruct, indent=4)  # indent for pretty formatting (optional)

# Write JSON string to file
with open(file_path, 'w') as f:
    f.write(json_data)

print(f"JSON data from codePlan has been saved to {file_path}")
# Out:
# JSON data from codePlan has been saved to prompt_data/part_one_4.json
